# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt





# %matplotlib inline

# %%
data = pd.read_csv('dataset.csv',nrows=500,engine='python')
data.head()
# Out:
#                                  Flow.ID      Source.IP  Source.Port  \
# 0    172.19.1.46-10.200.7.7-52422-3128-6    172.19.1.46        52422
# 1    172.19.1.46-10.200.7.7-52422-3128-6     10.200.7.7         3128
# 2   10.200.7.217-50.31.185.39-38848-80-6   50.31.185.39           80
# 3   10.200.7.217-50.31.185.39-38848-80-6   50.31.185.39           80
# 4  192.168.72.43-10.200.7.7-55961-3128-6  192.168.72.43        55961
#
#   Destination.IP  Destination.Port  Protocol           Timestamp  \
# 0     10.200.7.7              3128         6  26/04/201711:11:17
# 1    172.19.1.46             52422         6  26/04/201711:11:17
# 2   10.200.7.217             38848         6  26/04/201711:11:17
# 3   10.200.7.217             38848         6  26/04/201711:11:17
# 4     10.200.7.7              3128         6  26/04/201711:11:17
#
#    Flow.Duration  Total.Fwd.Packets  Total.Backward.Packets  ...  Active.Std  \
# 0          45523                 22                      55  ...           0
# 1              1                  2                       0  ...           0
# 2              1                  3                       0  ...           0
# 3            217                  1                       3  ...           0
# 4          78068                  5                       0  ...           0
#
#    Active.Max  Active.Min  Idle.Mean  Idle.Std  Idle.Max  Idle.Min   Label  \
# 0           0           0          0         0         0         0  BENIGN
# 1           0           0          0         0         0         0  BENIGN
# 2           0           0          0         0         0         0  BENIGN
# 3           0           0          0         0         0         0  BENIGN
# 4           0           0          0         0         0         0  BENIGN
#
#    L7Protocol  ProtocolName
# 0         131    HTTP_PROXY
# 1         131    HTTP_PROXY
# 2           7          HTTP
# 3           7          HTTP
# 4         131    HTTP_PROXY
#
# [5 rows x 87 columns]

# %%
data.shape
# Out:
# (500, 87)

# %%
data.columns
# Out:
# Index(['Flow.ID', 'Source.IP', 'Source.Port', 'Destination.IP',
#        'Destination.Port', 'Protocol', 'Timestamp', 'Flow.Duration',
#        'Total.Fwd.Packets', 'Total.Backward.Packets',
#        'Total.Length.of.Fwd.Packets', 'Total.Length.of.Bwd.Packets',
#        'Fwd.Packet.Length.Max', 'Fwd.Packet.Length.Min',
#        'Fwd.Packet.Length.Mean', 'Fwd.Packet.Length.Std',
#        'Bwd.Packet.Length.Max', 'Bwd.Packet.Length.Min',
#        'Bwd.Packet.Length.Mean', 'Bwd.Packet.Length.Std', 'Flow.Bytes.s',
#        'Flow.Packets.s', 'Flow.IAT.Mean', 'Flow.IAT.Std', 'Flow.IAT.Max',
#        'Flow.IAT.Min', 'Fwd.IAT.Total', 'Fwd.IAT.Mean', 'Fwd.IAT.Std',
#        'Fwd.IAT.Max', 'Fwd.IAT.Min', 'Bwd.IAT.Total', 'Bwd.IAT.Mean',
#        'Bwd.IAT.Std', 'Bwd.IAT.Max', 'Bwd.IAT.Min', 'Fwd.PSH.Flags',
#        'Bwd.PSH.Flags', 'Fwd.URG.Flags', 'Bwd.URG.Flags', 'Fwd.Header.Length',
#        'Bwd.Header.Length', 'Fwd.Packets.s', 'Bwd.Packets.s',
#        'Min.Packet.Length', 'Max.Packet.Length', 'Packet.Length.Mean',
#        'Packet.Length.Std', 'Packet.Length.Variance', 'FIN.Flag.Count',
#        'SYN.Flag.Count', 'RST.Flag.Count', 'PSH.Flag.Count', 'ACK.Flag.Count',
#        'URG.Flag.Count', 'CWE.Flag.Count', 'ECE.Flag.Count', 'Down.Up.Ratio',
#        'Average.Packet.Size', 'Avg.Fwd.Segment.Size', 'Avg.Bwd.Segment.Size',
#        'Fwd.Header.Length.1', 'Fwd.Avg.Bytes.Bulk', 'Fwd.Avg.Packets.Bulk',
#        'Fwd.Avg.Bulk.Rate', 'Bwd.Avg.Bytes.Bulk', 'Bwd.Avg.Packets.Bulk',
#        'Bwd.Avg.Bulk.Rate', 'Subflow.Fwd.Packets', 'Subflow.Fwd.Bytes',
#        'Subflow.Bwd.Packets', 'Subflow.Bwd.Bytes', 'Init_Win_bytes_forward',
#        'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward',
#        'Active.Mean', 'Active.Std', 'Active.Max', 'Active.Min', 'Idle.Mean',
#        'Idle.Std', 'Idle.Max', 'Idle.Min', 'Label', 'L7Protocol',
#        'ProtocolName'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 87 columns):
# Flow.ID                        500 non-null object
# Source.IP                      500 non-null object
# Source.Port                    500 non-null int64
# Destination.IP                 500 non-null object
# Destination.Port               500 non-null int64
# Protocol                       500 non-null int64
# Timestamp                      500 non-null object
# Flow.Duration                  500 non-null int64
# Total.Fwd.Packets              500 non-null int64
# Total.Backward.Packets         500 non-null int64
# Total.Length.of.Fwd.Packets    500 non-null int64
# Total.Length.of.Bwd.Packets    500 non-null int64
# Fwd.Packet.Length.Max          500 non-null int64
# Fwd.Packet.Length.Min          500 non-null int64
# Fwd.Packet.Length.Mean         500 non-null float64
# Fwd.Packet.Length.Std          500 non-null float64
# Bwd.Packet.Length.Max          500 non-null int64
# Bwd.Packet.Length.Min          500 non-null int64
# Bwd.Packet.Length.Mean         500 non-null float64
# Bwd.Packet.Length.Std          500 non-null float64
# Flow.Bytes.s                   500 non-null float64
# Flow.Packets.s                 500 non-null float64
# Flow.IAT.Mean                  500 non-null float64
# Flow.IAT.Std                   500 non-null float64
# Flow.IAT.Max                   500 non-null int64
# Flow.IAT.Min                   500 non-null int64
# Fwd.IAT.Total                  500 non-null int64
# Fwd.IAT.Mean                   500 non-null float64
# Fwd.IAT.Std                    500 non-null float64
# Fwd.IAT.Max                    500 non-null int64
# Fwd.IAT.Min                    500 non-null int64
# Bwd.IAT.Total                  500 non-null int64
# Bwd.IAT.Mean                   500 non-null float64
# Bwd.IAT.Std                    500 non-null float64
# Bwd.IAT.Max                    500 non-null int64
# Bwd.IAT.Min                    500 non-null int64
# Fwd.PSH.Flags                  500 non-null int64
# Bwd.PSH.Flags                  500 non-null int64
# Fwd.URG.Flags                  500 non-null int64
# Bwd.URG.Flags                  500 non-null int64
# Fwd.Header.Length              500 non-null int64
# Bwd.Header.Length              500 non-null int64
# Fwd.Packets.s                  500 non-null float64
# Bwd.Packets.s                  500 non-null float64
# Min.Packet.Length              500 non-null int64
# Max.Packet.Length              500 non-null int64
# Packet.Length.Mean             500 non-null float64
# Packet.Length.Std              500 non-null float64
# Packet.Length.Variance         500 non-null float64
# FIN.Flag.Count                 500 non-null int64
# SYN.Flag.Count                 500 non-null int64
# RST.Flag.Count                 500 non-null int64
# PSH.Flag.Count                 500 non-null int64
# ACK.Flag.Count                 500 non-null int64
# URG.Flag.Count                 500 non-null int64
# CWE.Flag.Count                 500 non-null int64
# ECE.Flag.Count                 500 non-null int64
# Down.Up.Ratio                  500 non-null int64
# Average.Packet.Size            500 non-null float64
# Avg.Fwd.Segment.Size           500 non-null float64
# Avg.Bwd.Segment.Size           500 non-null float64
# Fwd.Header.Length.1            500 non-null int64
# Fwd.Avg.Bytes.Bulk             500 non-null int64
# Fwd.Avg.Packets.Bulk           500 non-null int64
# Fwd.Avg.Bulk.Rate              500 non-null int64
# Bwd.Avg.Bytes.Bulk             500 non-null int64
# Bwd.Avg.Packets.Bulk           500 non-null int64
# Bwd.Avg.Bulk.Rate              500 non-null int64
# Subflow.Fwd.Packets            500 non-null int64
# Subflow.Fwd.Bytes              500 non-null int64
# Subflow.Bwd.Packets            500 non-null int64
# Subflow.Bwd.Bytes              500 non-null int64
# Init_Win_bytes_forward         500 non-null int64
# Init_Win_bytes_backward        500 non-null int64
# act_data_pkt_fwd               500 non-null int64
# min_seg_size_forward           500 non-null int64
# Active.Mean                    500 non-null int64
# Active.Std                     500 non-null int64
# Active.Max                     500 non-null int64
# Active.Min                     500 non-null int64
# Idle.Mean                      500 non-null int64
# Idle.Std                       500 non-null int64
# Idle.Max                       500 non-null int64
# Idle.Min                       500 non-null int64
# Label                          500 non-null object
# L7Protocol                     500 non-null int64
# ProtocolName                   500 non-null object
# dtypes: float64(20), int64(61), object(6)
# memory usage: 340.0+ KB

# %%
non_num_cols = [col for col in data.columns if data[col].dtype == 'O']
non_num_data = data[non_num_cols]
non_num_data
# Out:
#                                      Flow.ID      Source.IP  Destination.IP  \
# 0        172.19.1.46-10.200.7.7-52422-3128-6    172.19.1.46      10.200.7.7
# 1        172.19.1.46-10.200.7.7-52422-3128-6     10.200.7.7     172.19.1.46
# 2       10.200.7.217-50.31.185.39-38848-80-6   50.31.185.39    10.200.7.217
# 3       10.200.7.217-50.31.185.39-38848-80-6   50.31.185.39    10.200.7.217
# 4      192.168.72.43-10.200.7.7-55961-3128-6  192.168.72.43      10.200.7.7
# ..                                       ...            ...             ...
# 495     179.1.4.238-10.200.7.195-443-41578-6   10.200.7.195     179.1.4.238
# 496  216.58.202.225-10.200.7.195-443-44860-6   10.200.7.195  216.58.202.225
# 497    192.168.42.31-10.200.7.5-52688-3128-6  192.168.42.31      10.200.7.5
# 498    192.168.42.31-10.200.7.5-52689-3128-6  192.168.42.31      10.200.7.5
# 499    192.168.42.31-10.200.7.5-52688-3128-6     10.200.7.5   192.168.42.31
#
#               Timestamp   Label ProtocolName
# 0    26/04/201711:11:17  BENIGN   HTTP_PROXY
# 1    26/04/201711:11:17  BENIGN   HTTP_PROXY
# 2    26/04/201711:11:17  BENIGN         HTTP
# 3    26/04/201711:11:17  BENIGN         HTTP
# 4    26/04/201711:11:17  BENIGN   HTTP_PROXY
# ..                  ...     ...          ...
# 495  26/04/201711:11:18  BENIGN      YOUTUBE
# 496  26/04/201711:11:18  BENIGN      YOUTUBE
# 497  26/04/201711:11:19  BENIGN       GOOGLE
# 498  26/04/201711:11:21  BENIGN       GOOGLE
# 499  26/04/201711:11:21  BENIGN         HTTP
#
# [500 rows x 6 columns]

# %%
[(col, non_num_data[col].nunique()) for col in non_num_cols]
# Out:
# [('Flow.ID', 308),
#  ('Source.IP', 60),
#  ('Destination.IP', 81),
#  ('Timestamp', 5),
#  ('Label', 1),
#  ('ProtocolName', 12)]

# %%
def summarize_cat(col_name):
    sorted_values = sorted(non_num_data[col_name].value_counts().iteritems(), key = lambda x:x[1], reverse=True)
    remaining_per = 100
    for (value, count) in sorted_values:
        per = count / len(non_num_data) * 100
        if per >= 1:
            print(f'{value} : {per:.2f}%')
        else :
            print(f'Others : {remaining_per:.2f}%')
            break
        remaining_per = remaining_per - per

# %%
for col in non_num_cols:
    print(f"Summary of {col} column : ")
    summarize_cat(col)
    print('\n')
# Out:
# Summary of Flow.ID column :
# 192.168.180.51-10.200.7.4-57751-3128-6 : 1.00%
# 192.168.180.51-10.200.7.4-57754-3128-6 : 1.00%
# 192.168.180.51-10.200.7.4-57745-3128-6 : 1.00%
# Others : 97.00%
#
#
# Summary of Source.IP column :
# 10.200.7.217 : 11.60%
# 10.200.7.4 : 9.80%
# 10.200.7.194 : 8.60%
# 192.168.72.43 : 8.60%
# 10.200.7.9 : 8.40%
# 192.168.180.51 : 7.40%
# 10.200.7.199 : 5.00%
# 10.200.7.6 : 4.80%
# 10.200.7.5 : 3.80%
# 10.200.7.196 : 3.20%
# 192.168.180.37 : 2.60%
# 10.200.7.195 : 2.60%
# 10.200.7.7 : 2.20%
# 192.168.42.31 : 1.80%
# 192.168.10.47 : 1.60%
# 192.168.90.100 : 1.20%
# 192.168.180.29 : 1.20%
# 172.19.1.46 : 1.20%
# 192.168.32.49 : 1.20%
# Others : 13.20%
#
#
# Summary of Destination.IP column :
# 10.200.7.7 : 13.00%
# 192.168.180.51 : 9.20%
# 10.200.7.4 : 7.60%
# 192.168.180.37 : 6.20%
# 212.124.124.94 : 4.40%
# 10.200.7.6 : 4.40%
# 10.200.7.217 : 4.20%
# 10.200.7.9 : 4.20%
# 10.200.7.5 : 3.20%
# 69.172.216.55 : 3.00%
# 207.244.80.182 : 2.40%
# 104.91.156.236 : 2.40%
# 192.168.42.31 : 2.20%
# 192.168.32.49 : 1.80%
# 190.60.67.98 : 1.60%
# 179.1.4.238 : 1.20%
# 192.168.220.177 : 1.20%
# 216.58.202.226 : 1.00%
# 172.17.1.110 : 1.00%
# 213.239.207.69 : 1.00%
# 68.67.178.170 : 1.00%
# 192.168.10.47 : 1.00%
# 172.19.1.45 : 1.00%
# Others : 21.80%
#
#
# Summary of Timestamp column :
# 26/04/201711:11:18 : 27.60%
# 26/04/201711:11:20 : 23.40%
# 26/04/201711:11:19 : 22.80%
# 26/04/201711:11:17 : 15.40%
# 26/04/201711:11:21 : 10.80%
#
#
# Summary of Label column :
# BENIGN : 100.00%
#
#
# Summary of ProtocolName column :
# HTTP : 36.80%
# SSL : 15.20%
# HTTP_CONNECT : 13.60%
# HTTP_PROXY : 13.60%
# GOOGLE : 11.60%
# YOUTUBE : 6.00%
# CONTENT_FLASH : 1.00%
# Others : 2.20%

# %%
num_cols = list(set(data.columns) - set(non_num_cols))
num_cols
# Out:
# ['Fwd.Packet.Length.Std',
#  'Fwd.Packets.s',
#  'ECE.Flag.Count',
#  'Active.Std',
#  'Bwd.IAT.Std',
#  'Total.Backward.Packets',
#  'Down.Up.Ratio',
#  'Active.Max',
#  'Fwd.Packet.Length.Min',
#  'Bwd.PSH.Flags',
#  'Fwd.IAT.Max',
#  'Packet.Length.Variance',
#  'Fwd.Avg.Bulk.Rate',
#  'Total.Fwd.Packets',
#  'ACK.Flag.Count',
#  'Destination.Port',
#  'Flow.Packets.s',
#  'Fwd.Packet.Length.Max',
#  'Packet.Length.Mean',
#  'L7Protocol',
#  'Subflow.Bwd.Bytes',
#  'Fwd.IAT.Mean',
#  'Bwd.Header.Length',
#  'Bwd.IAT.Total',
#  'Packet.Length.Std',
#  'Fwd.PSH.Flags',
#  'Avg.Bwd.Segment.Size',
#  'min_seg_size_forward',
#  'SYN.Flag.Count',
#  'Idle.Min',
#  'Fwd.Header.Length',
#  'Bwd.Packet.Length.Mean',
#  'Min.Packet.Length',
#  'RST.Flag.Count',
#  'Protocol',
#  'Active.Mean',
#  'Subflow.Fwd.Bytes',
#  'Fwd.URG.Flags',
#  'Active.Min',
#  'Bwd.URG.Flags',
#  'FIN.Flag.Count',
#  'Init_Win_bytes_forward',
#  'Total.Length.of.Bwd.Packets',
#  'Bwd.IAT.Min',
#  'PSH.Flag.Count',
#  'Bwd.Avg.Packets.Bulk',
#  'Fwd.IAT.Total',
#  'Flow.Bytes.s',
#  'Fwd.IAT.Min',
#  'Bwd.IAT.Max',
#  'Source.Port',
#  'Bwd.Packet.Length.Std',
#  'Bwd.Packet.Length.Max',
#  'Bwd.Packet.Length.Min',
#  'Max.Packet.Length',
#  'Avg.Fwd.Segment.Size',
#  'Idle.Mean',
#  'URG.Flag.Count',
#  'Total.Length.of.Fwd.Packets',
#  'Fwd.Avg.Bytes.Bulk',
#  'Init_Win_bytes_backward',
#  'act_data_pkt_fwd',
#  'Flow.IAT.Mean',
#  'Subflow.Fwd.Packets',
#  'Bwd.IAT.Mean',
#  'Bwd.Avg.Bytes.Bulk',
#  'Fwd.Avg.Packets.Bulk',
#  'Flow.IAT.Min',
#  'Fwd.IAT.Std',
#  'Bwd.Avg.Bulk.Rate',
#  'Idle.Max',
#  'Flow.IAT.Std',
#  'CWE.Flag.Count',
#  'Flow.IAT.Max',
#  'Flow.Duration',
#  'Fwd.Header.Length.1',
#  'Average.Packet.Size',
#  'Bwd.Packets.s',
#  'Fwd.Packet.Length.Mean',
#  'Subflow.Bwd.Packets',
#  'Idle.Std']

# %%
data[num_cols].describe()
# Out:
#        Fwd.Packet.Length.Std  Fwd.Packets.s  ECE.Flag.Count  Active.Std  \
# count             500.000000   5.000000e+02           500.0       500.0
# mean              241.902592   2.324820e+05             0.0         0.0
# std               325.166719   6.481636e+05             0.0         0.0
# min                 0.000000   1.625864e+00             0.0         0.0
# 25%                 0.000000   2.307298e+01             0.0         0.0
# 50%               111.759877   1.046533e+02             0.0         0.0
# 75%               348.989854   1.467931e+04             0.0         0.0
# max              2257.279410   5.000000e+06             0.0         0.0
#
#          Bwd.IAT.Std  Total.Backward.Packets  Down.Up.Ratio  Active.Max  \
# count     500.000000              500.000000     500.000000       500.0
# mean    23801.932780               22.564000       1.086000         0.0
# std     45006.786111               80.782508       1.816922         0.0
# min         0.000000                0.000000       0.000000         0.0
# 25%         0.000000                0.000000       0.000000         0.0
# 50%         0.250000                2.500000       0.000000         0.0
# 75%     31323.239416               11.000000       1.000000         0.0
# max    386693.343772              751.000000      14.000000         0.0
#
#        Fwd.Packet.Length.Min  Bwd.PSH.Flags  ...   Flow.IAT.Std  \
# count             500.000000          500.0  ...     500.000000
# mean                2.708000            0.0  ...   54299.283442
# std                 7.807474            0.0  ...  119352.614671
# min                 0.000000            0.0  ...       0.000000
# 25%                 0.000000            0.0  ...       0.000000
# 50%                 0.000000            0.0  ...   12775.461567
# 75%                 6.000000            0.0  ...   49772.522937
# max                63.000000            0.0  ...  864237.258858
#
#        CWE.Flag.Count  Flow.IAT.Max  Flow.Duration  Fwd.Header.Length.1  \
# count           500.0  5.000000e+02   5.000000e+02           500.000000
# mean              0.0  2.400524e+05   3.879996e+05           421.936000
# std               0.0  4.967697e+05   6.443466e+05          1173.386909
# min               0.0  1.000000e+00   1.000000e+00            20.000000
# 25%               0.0  1.340000e+02   1.415000e+02            40.000000
# 50%               0.0  4.500550e+04   8.557950e+04           120.000000
# 75%               0.0  2.033592e+05   4.383262e+05           275.000000
# max               0.0  2.939125e+06   3.676541e+06         11808.000000
#
#        Average.Packet.Size  Bwd.Packets.s  Fwd.Packet.Length.Mean  \
# count           500.000000     500.000000              500.000000
# mean            313.961906     772.576828              182.994083
# std             485.212741    5282.922255              334.401195
# min               0.000000       0.000000                0.000000
# 25%               9.000000       0.000000                6.000000
# 50%              92.886781       8.491922               61.200000
# 75%             372.494737      79.807989              197.942857
# max            3330.333333  103448.275862             2305.544118
#
#        Subflow.Bwd.Packets  Idle.Std
# count           500.000000     500.0
# mean             22.564000       0.0
# std              80.782508       0.0
# min               0.000000       0.0
# 25%               0.000000       0.0
# 50%               2.500000       0.0
# 75%              11.000000       0.0
# max             751.000000       0.0
#
# [8 rows x 81 columns]

# %%
[col for col in num_cols if data[col].isnull().any()]
# Out:
# []

# %%
cols_for_hist = [col for col in num_cols if data[col].nunique() <= 50]
cols_for_hist, len(cols_for_hist)
# Out:
# (['ECE.Flag.Count',
#   'Active.Std',
#   'Down.Up.Ratio',
#   'Active.Max',
#   'Fwd.Packet.Length.Min',
#   'Bwd.PSH.Flags',
#   'Fwd.Avg.Bulk.Rate',
#   'ACK.Flag.Count',
#   'L7Protocol',
#   'Fwd.PSH.Flags',
#   'min_seg_size_forward',
#   'SYN.Flag.Count',
#   'Idle.Min',
#   'Min.Packet.Length',
#   'RST.Flag.Count',
#   'Protocol',
#   'Active.Mean',
#   'Fwd.URG.Flags',
#   'Active.Min',
#   'Bwd.URG.Flags',
#   'FIN.Flag.Count',
#   'PSH.Flag.Count',
#   'Bwd.Avg.Packets.Bulk',
#   'Bwd.Packet.Length.Min',
#   'Idle.Mean',
#   'URG.Flag.Count',
#   'Fwd.Avg.Bytes.Bulk',
#   'Bwd.Avg.Bytes.Bulk',
#   'Fwd.Avg.Packets.Bulk',
#   'Bwd.Avg.Bulk.Rate',
#   'Idle.Max',
#   'CWE.Flag.Count',
#   'Idle.Std'],
#  33)

# %%
cols_for_desc = [col for col in num_cols if data[col].nunique() > 50]
cols_for_desc
# Out:
# ['Fwd.Packet.Length.Std',
#  'Fwd.Packets.s',
#  'Bwd.IAT.Std',
#  'Total.Backward.Packets',
#  'Fwd.IAT.Max',
#  'Packet.Length.Variance',
#  'Total.Fwd.Packets',
#  'Destination.Port',
#  'Flow.Packets.s',
#  'Fwd.Packet.Length.Max',
#  'Packet.Length.Mean',
#  'Subflow.Bwd.Bytes',
#  'Fwd.IAT.Mean',
#  'Bwd.Header.Length',
#  'Bwd.IAT.Total',
#  'Packet.Length.Std',
#  'Avg.Bwd.Segment.Size',
#  'Fwd.Header.Length',
#  'Bwd.Packet.Length.Mean',
#  'Subflow.Fwd.Bytes',
#  'Init_Win_bytes_forward',
#  'Total.Length.of.Bwd.Packets',
#  'Bwd.IAT.Min',
#  'Fwd.IAT.Total',
#  'Flow.Bytes.s',
#  'Fwd.IAT.Min',
#  'Bwd.IAT.Max',
#  'Source.Port',
#  'Bwd.Packet.Length.Std',
#  'Bwd.Packet.Length.Max',
#  'Max.Packet.Length',
#  'Avg.Fwd.Segment.Size',
#  'Total.Length.of.Fwd.Packets',
#  'Init_Win_bytes_backward',
#  'act_data_pkt_fwd',
#  'Flow.IAT.Mean',
#  'Subflow.Fwd.Packets',
#  'Bwd.IAT.Mean',
#  'Flow.IAT.Min',
#  'Fwd.IAT.Std',
#  'Flow.IAT.Std',
#  'Flow.IAT.Max',
#  'Flow.Duration',
#  'Fwd.Header.Length.1',
#  'Average.Packet.Size',
#  'Bwd.Packets.s',
#  'Fwd.Packet.Length.Mean',
#  'Subflow.Bwd.Packets']

# %%
corr = data[num_cols].corr()

# %%
ipdata = data.copy()

# %%
print("No. of unique values in Timestamp column :",ipdata['Timestamp'].nunique())
print("No. of unique values in FlowID column :",ipdata['Flow.ID'].nunique())
# Out:
# No. of unique values in Timestamp column : 5
# No. of unique values in FlowID column : 308

# %%
ipdata.drop(['Timestamp', 'Flow.ID'], axis = 1, inplace = True)

# %%
single_unique_cols = [col for col in ipdata.columns if ipdata[col].nunique() == 1]
single_unique_cols
# Out:
# ['Protocol',
#  'Bwd.PSH.Flags',
#  'Fwd.URG.Flags',
#  'Bwd.URG.Flags',
#  'RST.Flag.Count',
#  'CWE.Flag.Count',
#  'ECE.Flag.Count',
#  'Fwd.Avg.Bytes.Bulk',
#  'Fwd.Avg.Packets.Bulk',
#  'Fwd.Avg.Bulk.Rate',
#  'Bwd.Avg.Bytes.Bulk',
#  'Bwd.Avg.Packets.Bulk',
#  'Bwd.Avg.Bulk.Rate',
#  'Active.Mean',
#  'Active.Std',
#  'Active.Max',
#  'Active.Min',
#  'Idle.Mean',
#  'Idle.Std',
#  'Idle.Max',
#  'Idle.Min',
#  'Label']

# %%
ipdata.drop(single_unique_cols, axis = 1, inplace = True)

# %%
ip_add_cols = ['Source.IP', 'Source.Port', 'Destination.IP', 'Destination.Port']
ipdata[ip_add_cols]
# Out:
#          Source.IP  Source.Port  Destination.IP  Destination.Port
# 0      172.19.1.46        52422      10.200.7.7              3128
# 1       10.200.7.7         3128     172.19.1.46             52422
# 2     50.31.185.39           80    10.200.7.217             38848
# 3     50.31.185.39           80    10.200.7.217             38848
# 4    192.168.72.43        55961      10.200.7.7              3128
# ..             ...          ...             ...               ...
# 495   10.200.7.195        41578     179.1.4.238               443
# 496   10.200.7.195        44860  216.58.202.225               443
# 497  192.168.42.31        52688      10.200.7.5              3128
# 498  192.168.42.31        52689      10.200.7.5              3128
# 499     10.200.7.5         3128   192.168.42.31             52688
#
# [500 rows x 4 columns]

# %%
ipdata.drop(ip_add_cols, axis = 1, inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder().fit(ipdata['ProtocolName'])
ipdata['ProtocolName'] = encoder.fit_transform(ipdata['ProtocolName'])
ipdata['ProtocolName']
# Out:
# 0       7
# 1       7
# 2       5
# 3       5
# 4       7
#        ..
# 495    11
# 496    11
# 497     4
# 498     4
# 499     5
# Name: ProtocolName, Length: 500, dtype: int64

# %%
ipdata.head(10)
# Out:
#    Flow.Duration  Total.Fwd.Packets  Total.Backward.Packets  \
# 0          45523                 22                      55
# 1              1                  2                       0
# 2              1                  3                       0
# 3            217                  1                       3
# 4          78068                  5                       0
# 5         105069                136                       0
# 6         104443                  5                       0
# 7          11002                  3                      12
# 8         108503                 10                       6
# 9         118415                  7                       0
#
#    Total.Length.of.Fwd.Packets  Total.Length.of.Bwd.Packets  \
# 0                          132                       110414
# 1                           12                            0
# 2                          674                            0
# 3                            0                            0
# 4                         1076                            0
# 5                       313554                            0
# 6                         1076                            0
# 7                          232                         3664
# 8                         6904                         1302
# 9                         2210                            0
#
#    Fwd.Packet.Length.Max  Fwd.Packet.Length.Min  Fwd.Packet.Length.Mean  \
# 0                      6                      6                6.000000
# 1                      6                      6                6.000000
# 2                    337                      0              224.666667
# 3                      0                      0                0.000000
# 4                    529                      6              215.200000
# 5                   5840                      6             2305.544118
# 6                    529                      6              215.200000
# 7                    226                      0               77.333333
# 8                   1448                      0              690.400000
# 9                   1096                      0              315.714286
#
#    Fwd.Packet.Length.Std  Bwd.Packet.Length.Max  ...  Subflow.Fwd.Packets  \
# 0               0.000000                   4380  ...                   22
# 1               0.000000                      0  ...                    2
# 2             194.567041                      0  ...                    3
# 3               0.000000                      0  ...                    1
# 4             286.458898                      0  ...                    5
# 5            1220.822406                      0  ...                  136
# 6             286.458898                      0  ...                    5
# 7             128.784057                   3628  ...                    3
# 8             660.894209                   1302  ...                   10
# 9             533.043374                      0  ...                    7
#
#    Subflow.Fwd.Bytes  Subflow.Bwd.Packets  Subflow.Bwd.Bytes  \
# 0                132                   55             110414
# 1                 12                    0                  0
# 2                674                    0                  0
# 3                  0                    3                  0
# 4               1076                    0                  0
# 5             313554                    0                  0
# 6               1076                    0                  0
# 7                232                   12               3664
# 8               6904                    6               1302
# 9               2210                    0                  0
#
#    Init_Win_bytes_forward  Init_Win_bytes_backward  act_data_pkt_fwd  \
# 0                     256                      490                21
# 1                     490                       -1                 1
# 2                     888                       -1                 1
# 3                     888                      490                 0
# 4                     253                       -1                 4
# 5                     254                       -1               135
# 6                     253                       -1                 4
# 7                    8192                      245                 2
# 8                      60                     1000                 7
# 9                    8192                       -1                 5
#
#    min_seg_size_forward  L7Protocol  ProtocolName
# 0                    20         131             7
# 1                    20         131             7
# 2                    32           7             5
# 3                    32           7             5
# 4                    20         131             7
# 5                    20         131             7
# 6                    20         131             7
# 7                    20         130             6
# 8                    32          91             9
# 9                    20         126             4
#
# [10 rows x 59 columns]

# %%
ipdata.shape
# Out:
# (500, 59)

# %%
data.dropna(inplace = True)

# %%
def ipInfo(addr=''):
    from urllib.request import urlopen
    from json import load
    if addr == '':
        url = 'https://ipinfo.io/json'
    else:
        url = 'https://ipinfo.io/' + addr + '/json'
    res = urlopen(url)
    
    data = load(res)
    
    for attr in data.keys():
        
        print(attr,' '*13+'\t->\t',data[attr])
data.drop(columns =["Timestamp"], inplace = True)

# %%
data.drop(columns =["Label"], inplace = True)
df2 = data

# %%
df2.drop(columns =["Source.IP", "Source.Port", "Destination.IP", "Destination.Port"], inplace = True) #better way is to replace it with country using some lib like geo2ip but I am lazy
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
df2["labels"] = lb_make.fit_transform(df2["ProtocolName"])
df2[["ProtocolName", "labels"]].head(11)
# Out:
#     ProtocolName  labels
# 0     HTTP_PROXY       7
# 1     HTTP_PROXY       7
# 2           HTTP       5
# 3           HTTP       5
# 4     HTTP_PROXY       7
# 5     HTTP_PROXY       7
# 6     HTTP_PROXY       7
# 7   HTTP_CONNECT       6
# 8            SSL       9
# 9         GOOGLE       4
# 10    HTTP_PROXY       7

# %%
from sklearn.model_selection import train_test_split
# !pip install '/content/drive/My Drive/lib-0.1.0-py3-none-any.whl'
y = df2.iloc[:,-1]
from lib.utils import *
X,y=scaler_transform(df2)
ac=[]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)
X_train.shape, y_train.shape
ac=[]
# Out:
# ERROR: Invalid requirement: "'/content/drive/My"

# %%
ac=[]

import random
from sklearn.linear_model import Ridge
model = Ridge(alpha=1.0)

def objective_function(x):
    return x**2  


class Particle:
    def __init__(self):
        self.position = random.uniform(-5, 5)  
        self.velocity = random.uniform(-1, 1)  
        self.best_position = self.position  
        self.best_score = float('inf')  #

    def particle_swarm_optimization(self,num_particles, num_iterations):
        particles = [Particle() for _ in range(num_particles)]  
        global_best_position = None  
        global_best_score = float('inf')  

        for _ in range(num_iterations):
            for particle in particles:
                score = objective_function(particle.position)  
                if score < particle.best_score:
                    particle.best_score = score
                    particle.best_position = particle.position

                if score < global_best_score:
                    global_best_score = score
                    global_best_position = particle.position


                inertia_weight = 0.5
                cognitive_weight = 0.5
                social_weight = 0.5
                particle.velocity = (inertia_weight * particle.velocity +
                                     cognitive_weight * random.random() * (particle.best_position - particle.position) +
                                     social_weight * random.random() * (global_best_position - particle.position))
                particle.position += particle.velocity

        return global_best_position, global_best_score

    def train(self,X_train,y_train,X_test):
        model.fit(X_train,y_train)
        y_pred=model.predict(X_test)
        return y_pred

num_particles = 30  
num_iterations = 100 
p=Particle()
best_position, best_score =p.particle_swarm_optimization(num_particles, num_iterations)

y_pred=p.train(X_train,y_train,X_test)
print("Best Position:", best_position)
print("Best Score:", best_score)
ac.append(accuracy_score(y_pred,y_train,sample_weight=0.2)*100)
# Out:
# Best Position: -1.1942985042293405e-18
# Best Score: 1.42634891720444e-36

# %%
import random
import math

class WhaleOptimizationAlgorithm:
    def __init__(self, num_whales=10, num_iterations=100, search_space_lower_bound=-10, search_space_upper_bound=10):
        self.num_whales = num_whales
        self.num_iterations = num_iterations
        self.search_space_lower_bound = search_space_lower_bound
        self.search_space_upper_bound = search_space_upper_bound

    def _initialize_whales(self):
        return [random.uniform(self.search_space_lower_bound, self.search_space_upper_bound) for _ in range(self.num_whales)]

    def _fitness_function(self, solution):
        
        return sum(x ** 2 for x in solution)

    def optimize(self):
        whales = self._initialize_whales()
        best_solution = None
        best_fitness = float('inf')

        for iteration in range(self.num_iterations):
            a = 2 - iteration * ((2) / self.num_iterations)  

            for i in range(self.num_whales):
                A = 2 * a * random.random() - a  
                C = 2 * random.random()  

                p = random.random()  

                if p < 0.5:
                    if abs(A) < 1:
                        D = abs(C * best_solution[i] - whales[i])
                        new_solution = best_solution[i] - A * D  
                    else:
                        random_whale = random.choice(whales)
                        D = abs(C * random_whale - whales[i])
                        new_solution = random_whale - A * D  
                else:
                    distance_to_best = abs(best_solution[i] - whales[i])
                    new_solution = distance_to_best * math.exp(b * A) * math.cos(2 * math.pi * A) + best_solution[i]  # Equation (2.6)


                new_solution = max(min(new_solution, self.search_space_upper_bound), self.search_space_lower_bound)

              
                fitness_new = self._fitness_function(new_solution)
                fitness_whale = self._fitness_function(whales[i])

                if fitness_new < fitness_whale:
                    whales[i] = new_solution

                    if fitness_new < best_fitness:
                        best_solution = new_solution
                        best_fitness = fitness_new

        return best_solution, best_fitness
    def train(self,X_train,y_train,X_test):
        model.fit(X_train,y_train)
        y_pred=model.predict(X_test)
        return y_pred



num_whales = 10
num_iterations = 100
search_space_lower_bound = -10
search_space_upper_bound = 10

woa = WhaleOptimizationAlgorithm(num_whales=num_whales, num_iterations=num_iterations, search_space_lower_bound=search_space_lower_bound, search_space_upper_bound=search_space_upper_bound)
y_pred=woa.train(X_train,y_train,X_test)

ac.append(accuracy_score(y_pred,y_train,sample_weight=0.4)*100)

# %%
from scipy import signal
import numpy as np
sig = np.repeat([0., 1., 1., 0., 1., 0., 0., 1.], 128)
sig_noise = sig + np.random.randn(len(sig))
corr = signal.correlate(sig_noise, np.ones(128), mode='same') / 128
import matplotlib.pyplot as plt
clock = np.arange(64, len(sig), 128)
fig, (ax_orig, ax_noise, ax_corr) = plt.subplots(3, 1, sharex=True)
ax_orig.plot(sig)
ax_orig.plot(clock, sig[clock], 'ro')
ax_orig.set_title('Original signal')
ax_noise.plot(sig_noise)
ax_noise.set_title('Signal with noise')
ax_corr.plot(corr)
ax_corr.plot(clock, corr[clock], 'ro')
ax_corr.axhline(0.5, ls=':')
ax_corr.set_title('Cross-correlated with rectangular pulse')
ax_orig.margins(0, 0.1)
fig.tight_layout()
fig.show()
# Out:
# C:\Users\aswin\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
import numpy as np
import seaborn as sns
import matplotlib as plt

plt.style.use('dark_background')
x=['PSO','Whael Optimization']
 
ax=sns.barplot(x,ac[:2])
ax.set_title('Accuracy comparison')
ax.set_ylabel('Accuracy')
#ax.yaxis.set_major_locator(ticker.LinearLocator())
print("the accuracy of {} is {} and {} is {}".format(x[0],ac[0],x[1],ac[1]))
ax.set_ylim(50,100)
import pandas as pd
data={'Agorithms':x,
     "accuracy":ac[:2]}
df=pd.DataFrame(data)
df.head()
# Out:
# the accuracy of PSO is 95.44 and Whael Optimization is 91.4
# C:\Users\aswin\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#             Agorithms  accuracy
# 0                 PSO     95.44
# 1  Whael Optimization     91.40

# %%
ac
# Out:
# [95.44, 91.4]
