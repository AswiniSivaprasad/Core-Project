# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt





# %matplotlib inline

# %%
data = pd.read_csv('dataset.csv',nrows=500,engine='python')
data.head()
# Out:
#                                  Flow.ID      Source.IP  Source.Port  \
# 0    172.19.1.46-10.200.7.7-52422-3128-6    172.19.1.46        52422
# 1    172.19.1.46-10.200.7.7-52422-3128-6     10.200.7.7         3128
# 2   10.200.7.217-50.31.185.39-38848-80-6   50.31.185.39           80
# 3   10.200.7.217-50.31.185.39-38848-80-6   50.31.185.39           80
# 4  192.168.72.43-10.200.7.7-55961-3128-6  192.168.72.43        55961
#
#   Destination.IP  Destination.Port  Protocol           Timestamp  \
# 0     10.200.7.7              3128         6  26/04/201711:11:17
# 1    172.19.1.46             52422         6  26/04/201711:11:17
# 2   10.200.7.217             38848         6  26/04/201711:11:17
# 3   10.200.7.217             38848         6  26/04/201711:11:17
# 4     10.200.7.7              3128         6  26/04/201711:11:17
#
#    Flow.Duration  Total.Fwd.Packets  Total.Backward.Packets  ...  Active.Std  \
# 0          45523                 22                      55  ...           0
# 1              1                  2                       0  ...           0
# 2              1                  3                       0  ...           0
# 3            217                  1                       3  ...           0
# 4          78068                  5                       0  ...           0
#
#    Active.Max  Active.Min  Idle.Mean  Idle.Std  Idle.Max  Idle.Min   Label  \
# 0           0           0          0         0         0         0  BENIGN
# 1           0           0          0         0         0         0  BENIGN
# 2           0           0          0         0         0         0  BENIGN
# 3           0           0          0         0         0         0  BENIGN
# 4           0           0          0         0         0         0  BENIGN
#
#    L7Protocol  ProtocolName
# 0         131    HTTP_PROXY
# 1         131    HTTP_PROXY
# 2           7          HTTP
# 3           7          HTTP
# 4         131    HTTP_PROXY
#
# [5 rows x 87 columns]

# %%
data.shape
# Out:
# (500, 87)

# %%
data.columns
# Out:
# Index(['Flow.ID', 'Source.IP', 'Source.Port', 'Destination.IP',
#        'Destination.Port', 'Protocol', 'Timestamp', 'Flow.Duration',
#        'Total.Fwd.Packets', 'Total.Backward.Packets',
#        'Total.Length.of.Fwd.Packets', 'Total.Length.of.Bwd.Packets',
#        'Fwd.Packet.Length.Max', 'Fwd.Packet.Length.Min',
#        'Fwd.Packet.Length.Mean', 'Fwd.Packet.Length.Std',
#        'Bwd.Packet.Length.Max', 'Bwd.Packet.Length.Min',
#        'Bwd.Packet.Length.Mean', 'Bwd.Packet.Length.Std', 'Flow.Bytes.s',
#        'Flow.Packets.s', 'Flow.IAT.Mean', 'Flow.IAT.Std', 'Flow.IAT.Max',
#        'Flow.IAT.Min', 'Fwd.IAT.Total', 'Fwd.IAT.Mean', 'Fwd.IAT.Std',
#        'Fwd.IAT.Max', 'Fwd.IAT.Min', 'Bwd.IAT.Total', 'Bwd.IAT.Mean',
#        'Bwd.IAT.Std', 'Bwd.IAT.Max', 'Bwd.IAT.Min', 'Fwd.PSH.Flags',
#        'Bwd.PSH.Flags', 'Fwd.URG.Flags', 'Bwd.URG.Flags', 'Fwd.Header.Length',
#        'Bwd.Header.Length', 'Fwd.Packets.s', 'Bwd.Packets.s',
#        'Min.Packet.Length', 'Max.Packet.Length', 'Packet.Length.Mean',
#        'Packet.Length.Std', 'Packet.Length.Variance', 'FIN.Flag.Count',
#        'SYN.Flag.Count', 'RST.Flag.Count', 'PSH.Flag.Count', 'ACK.Flag.Count',
#        'URG.Flag.Count', 'CWE.Flag.Count', 'ECE.Flag.Count', 'Down.Up.Ratio',
#        'Average.Packet.Size', 'Avg.Fwd.Segment.Size', 'Avg.Bwd.Segment.Size',
#        'Fwd.Header.Length.1', 'Fwd.Avg.Bytes.Bulk', 'Fwd.Avg.Packets.Bulk',
#        'Fwd.Avg.Bulk.Rate', 'Bwd.Avg.Bytes.Bulk', 'Bwd.Avg.Packets.Bulk',
#        'Bwd.Avg.Bulk.Rate', 'Subflow.Fwd.Packets', 'Subflow.Fwd.Bytes',
#        'Subflow.Bwd.Packets', 'Subflow.Bwd.Bytes', 'Init_Win_bytes_forward',
#        'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward',
#        'Active.Mean', 'Active.Std', 'Active.Max', 'Active.Min', 'Idle.Mean',
#        'Idle.Std', 'Idle.Max', 'Idle.Min', 'Label', 'L7Protocol',
#        'ProtocolName'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 87 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Flow.ID                      500 non-null    object
#  1   Source.IP                    500 non-null    object
#  2   Source.Port                  500 non-null    int64
#  3   Destination.IP               500 non-null    object
#  4   Destination.Port             500 non-null    int64
#  5   Protocol                     500 non-null    int64
#  6   Timestamp                    500 non-null    object
#  7   Flow.Duration                500 non-null    int64
#  8   Total.Fwd.Packets            500 non-null    int64
#  9   Total.Backward.Packets       500 non-null    int64
#  10  Total.Length.of.Fwd.Packets  500 non-null    int64
#  11  Total.Length.of.Bwd.Packets  500 non-null    int64
#  12  Fwd.Packet.Length.Max        500 non-null    int64
#  13  Fwd.Packet.Length.Min        500 non-null    int64
#  14  Fwd.Packet.Length.Mean       500 non-null    float64
#  15  Fwd.Packet.Length.Std        500 non-null    float64
#  16  Bwd.Packet.Length.Max        500 non-null    int64
#  17  Bwd.Packet.Length.Min        500 non-null    int64
#  18  Bwd.Packet.Length.Mean       500 non-null    float64
#  19  Bwd.Packet.Length.Std        500 non-null    float64
#  20  Flow.Bytes.s                 500 non-null    float64
#  21  Flow.Packets.s               500 non-null    float64
#  22  Flow.IAT.Mean                500 non-null    float64
#  23  Flow.IAT.Std                 500 non-null    float64
#  24  Flow.IAT.Max                 500 non-null    int64
#  25  Flow.IAT.Min                 500 non-null    int64
#  26  Fwd.IAT.Total                500 non-null    int64
#  27  Fwd.IAT.Mean                 500 non-null    float64
#  28  Fwd.IAT.Std                  500 non-null    float64
#  29  Fwd.IAT.Max                  500 non-null    int64
#  30  Fwd.IAT.Min                  500 non-null    int64
#  31  Bwd.IAT.Total                500 non-null    int64
#  32  Bwd.IAT.Mean                 500 non-null    float64
#  33  Bwd.IAT.Std                  500 non-null    float64
#  34  Bwd.IAT.Max                  500 non-null    int64
#  35  Bwd.IAT.Min                  500 non-null    int64
#  36  Fwd.PSH.Flags                500 non-null    int64
#  37  Bwd.PSH.Flags                500 non-null    int64
#  38  Fwd.URG.Flags                500 non-null    int64
#  39  Bwd.URG.Flags                500 non-null    int64
#  40  Fwd.Header.Length            500 non-null    int64
#  41  Bwd.Header.Length            500 non-null    int64
#  42  Fwd.Packets.s                500 non-null    float64
#  43  Bwd.Packets.s                500 non-null    float64
#  44  Min.Packet.Length            500 non-null    int64
#  45  Max.Packet.Length            500 non-null    int64
#  46  Packet.Length.Mean           500 non-null    float64
#  47  Packet.Length.Std            500 non-null    float64
#  48  Packet.Length.Variance       500 non-null    float64
#  49  FIN.Flag.Count               500 non-null    int64
#  50  SYN.Flag.Count               500 non-null    int64
#  51  RST.Flag.Count               500 non-null    int64
#  52  PSH.Flag.Count               500 non-null    int64
#  53  ACK.Flag.Count               500 non-null    int64
#  54  URG.Flag.Count               500 non-null    int64
#  55  CWE.Flag.Count               500 non-null    int64
#  56  ECE.Flag.Count               500 non-null    int64
#  57  Down.Up.Ratio                500 non-null    int64
#  58  Average.Packet.Size          500 non-null    float64
#  59  Avg.Fwd.Segment.Size         500 non-null    float64
#  60  Avg.Bwd.Segment.Size         500 non-null    float64
#  61  Fwd.Header.Length.1          500 non-null    int64
#  62  Fwd.Avg.Bytes.Bulk           500 non-null    int64
#  63  Fwd.Avg.Packets.Bulk         500 non-null    int64
#  64  Fwd.Avg.Bulk.Rate            500 non-null    int64
#  65  Bwd.Avg.Bytes.Bulk           500 non-null    int64
#  66  Bwd.Avg.Packets.Bulk         500 non-null    int64
#  67  Bwd.Avg.Bulk.Rate            500 non-null    int64
#  68  Subflow.Fwd.Packets          500 non-null    int64
#  69  Subflow.Fwd.Bytes            500 non-null    int64
#  70  Subflow.Bwd.Packets          500 non-null    int64
#  71  Subflow.Bwd.Bytes            500 non-null    int64
#  72  Init_Win_bytes_forward       500 non-null    int64
#  73  Init_Win_bytes_backward      500 non-null    int64
#  74  act_data_pkt_fwd             500 non-null    int64
#  75  min_seg_size_forward         500 non-null    int64
#  76  Active.Mean                  500 non-null    int64
#  77  Active.Std                   500 non-null    int64
#  78  Active.Max                   500 non-null    int64
#  79  Active.Min                   500 non-null    int64
#  80  Idle.Mean                    500 non-null    int64
#  81  Idle.Std                     500 non-null    int64
#  82  Idle.Max                     500 non-null    int64
#  83  Idle.Min                     500 non-null    int64
#  84  Label                        500 non-null    object
#  85  L7Protocol                   500 non-null    int64
#  86  ProtocolName                 500 non-null    object
# dtypes: float64(20), int64(61), object(6)
# memory usage: 340.0+ KB

# %%
non_num_cols = [col for col in data.columns if data[col].dtype == 'O']
non_num_data = data[non_num_cols]
non_num_data
# Out:
#                                      Flow.ID      Source.IP  Destination.IP  \
# 0        172.19.1.46-10.200.7.7-52422-3128-6    172.19.1.46      10.200.7.7
# 1        172.19.1.46-10.200.7.7-52422-3128-6     10.200.7.7     172.19.1.46
# 2       10.200.7.217-50.31.185.39-38848-80-6   50.31.185.39    10.200.7.217
# 3       10.200.7.217-50.31.185.39-38848-80-6   50.31.185.39    10.200.7.217
# 4      192.168.72.43-10.200.7.7-55961-3128-6  192.168.72.43      10.200.7.7
# ..                                       ...            ...             ...
# 495     179.1.4.238-10.200.7.195-443-41578-6   10.200.7.195     179.1.4.238
# 496  216.58.202.225-10.200.7.195-443-44860-6   10.200.7.195  216.58.202.225
# 497    192.168.42.31-10.200.7.5-52688-3128-6  192.168.42.31      10.200.7.5
# 498    192.168.42.31-10.200.7.5-52689-3128-6  192.168.42.31      10.200.7.5
# 499    192.168.42.31-10.200.7.5-52688-3128-6     10.200.7.5   192.168.42.31
#
#               Timestamp   Label ProtocolName
# 0    26/04/201711:11:17  BENIGN   HTTP_PROXY
# 1    26/04/201711:11:17  BENIGN   HTTP_PROXY
# 2    26/04/201711:11:17  BENIGN         HTTP
# 3    26/04/201711:11:17  BENIGN         HTTP
# 4    26/04/201711:11:17  BENIGN   HTTP_PROXY
# ..                  ...     ...          ...
# 495  26/04/201711:11:18  BENIGN      YOUTUBE
# 496  26/04/201711:11:18  BENIGN      YOUTUBE
# 497  26/04/201711:11:19  BENIGN       GOOGLE
# 498  26/04/201711:11:21  BENIGN       GOOGLE
# 499  26/04/201711:11:21  BENIGN         HTTP
#
# [500 rows x 6 columns]

# %%
[(col, non_num_data[col].nunique()) for col in non_num_cols]
# Out:
# [('Flow.ID', 308),
#  ('Source.IP', 60),
#  ('Destination.IP', 81),
#  ('Timestamp', 5),
#  ('Label', 1),
#  ('ProtocolName', 12)]

# %%
def summarize_cat(col_name):
    sorted_values = sorted(non_num_data[col_name].value_counts().iteritems(), key = lambda x:x[1], reverse=True)
    remaining_per = 100
    for (value, count) in sorted_values:
        per = count / len(non_num_data) * 100
        if per >= 1:
            print(f'{value} : {per:.2f}%')
        else :
            print(f'Others : {remaining_per:.2f}%')
            break
        remaining_per = remaining_per - per

# %%
for col in non_num_cols:
    print(f"Summary of {col} column : ")
    summarize_cat(col)
    print('\n')
# Out:
# Summary of Flow.ID column :
# 192.168.180.51-10.200.7.4-57751-3128-6 : 1.00%
# 192.168.180.51-10.200.7.4-57754-3128-6 : 1.00%
# 192.168.180.51-10.200.7.4-57745-3128-6 : 1.00%
# Others : 97.00%
#
#
# Summary of Source.IP column :
# 10.200.7.217 : 11.60%
# 10.200.7.4 : 9.80%
# 192.168.72.43 : 8.60%
# 10.200.7.194 : 8.60%
# 10.200.7.9 : 8.40%
# 192.168.180.51 : 7.40%
# 10.200.7.199 : 5.00%
# 10.200.7.6 : 4.80%
# 10.200.7.5 : 3.80%
# 10.200.7.196 : 3.20%
# 192.168.180.37 : 2.60%
# 10.200.7.195 : 2.60%
# 10.200.7.7 : 2.20%
# 192.168.42.31 : 1.80%
# 192.168.10.47 : 1.60%
# 192.168.180.29 : 1.20%
# 192.168.90.100 : 1.20%
# 192.168.32.49 : 1.20%
# 172.19.1.46 : 1.20%
# Others : 13.20%
#
#
# Summary of Destination.IP column :
# 10.200.7.7 : 13.00%
# 192.168.180.51 : 9.20%
# 10.200.7.4 : 7.60%
# 192.168.180.37 : 6.20%
# 10.200.7.6 : 4.40%
# 212.124.124.94 : 4.40%
# 10.200.7.9 : 4.20%
# 10.200.7.217 : 4.20%
# 10.200.7.5 : 3.20%
# 69.172.216.55 : 3.00%
# 104.91.156.236 : 2.40%
# 207.244.80.182 : 2.40%
# 192.168.42.31 : 2.20%
# 192.168.32.49 : 1.80%
# 190.60.67.98 : 1.60%
# 179.1.4.238 : 1.20%
# 192.168.220.177 : 1.20%
# 213.239.207.69 : 1.00%
# 192.168.10.47 : 1.00%
# 216.58.202.226 : 1.00%
# 172.19.1.45 : 1.00%
# 68.67.178.170 : 1.00%
# 172.17.1.110 : 1.00%
# Others : 21.80%
#
#
# Summary of Timestamp column :
# 26/04/201711:11:18 : 27.60%
# 26/04/201711:11:20 : 23.40%
# 26/04/201711:11:19 : 22.80%
# 26/04/201711:11:17 : 15.40%
# 26/04/201711:11:21 : 10.80%
#
#
# Summary of Label column :
# BENIGN : 100.00%
#
#
# Summary of ProtocolName column :
# HTTP : 36.80%
# SSL : 15.20%
# HTTP_PROXY : 13.60%
# HTTP_CONNECT : 13.60%
# GOOGLE : 11.60%
# YOUTUBE : 6.00%
# CONTENT_FLASH : 1.00%
# Others : 2.20%

# %%
num_cols = list(set(data.columns) - set(non_num_cols))
num_cols
# Out:
# ['Fwd.Packet.Length.Min',
#  'Flow.IAT.Std',
#  'Flow.IAT.Max',
#  'Total.Fwd.Packets',
#  'Fwd.IAT.Min',
#  'Subflow.Bwd.Bytes',
#  'Idle.Mean',
#  'Idle.Max',
#  'Fwd.Packet.Length.Std',
#  'Packet.Length.Mean',
#  'Bwd.URG.Flags',
#  'Active.Std',
#  'Bwd.Avg.Packets.Bulk',
#  'Active.Mean',
#  'Bwd.Packet.Length.Min',
#  'Bwd.Avg.Bytes.Bulk',
#  'Init_Win_bytes_forward',
#  'RST.Flag.Count',
#  'Fwd.Header.Length.1',
#  'Idle.Min',
#  'Fwd.IAT.Max',
#  'Avg.Bwd.Segment.Size',
#  'Fwd.Avg.Packets.Bulk',
#  'Source.Port',
#  'Bwd.Packet.Length.Std',
#  'L7Protocol',
#  'Flow.IAT.Min',
#  'Fwd.IAT.Mean',
#  'Protocol',
#  'Bwd.IAT.Mean',
#  'Bwd.Packet.Length.Max',
#  'Total.Backward.Packets',
#  'Fwd.Packet.Length.Max',
#  'Flow.Duration',
#  'Flow.IAT.Mean',
#  'Fwd.Packets.s',
#  'Bwd.PSH.Flags',
#  'URG.Flag.Count',
#  'FIN.Flag.Count',
#  'Packet.Length.Std',
#  'Average.Packet.Size',
#  'Flow.Bytes.s',
#  'Idle.Std',
#  'Fwd.Avg.Bytes.Bulk',
#  'Bwd.IAT.Std',
#  'Active.Min',
#  'Destination.Port',
#  'Min.Packet.Length',
#  'Total.Length.of.Fwd.Packets',
#  'Bwd.Avg.Bulk.Rate',
#  'Subflow.Fwd.Packets',
#  'Bwd.IAT.Max',
#  'Fwd.Header.Length',
#  'act_data_pkt_fwd',
#  'Bwd.Packets.s',
#  'ACK.Flag.Count',
#  'Flow.Packets.s',
#  'Subflow.Bwd.Packets',
#  'min_seg_size_forward',
#  'PSH.Flag.Count',
#  'Bwd.Packet.Length.Mean',
#  'Fwd.Packet.Length.Mean',
#  'Total.Length.of.Bwd.Packets',
#  'Avg.Fwd.Segment.Size',
#  'Down.Up.Ratio',
#  'Fwd.IAT.Std',
#  'Fwd.PSH.Flags',
#  'Fwd.IAT.Total',
#  'Packet.Length.Variance',
#  'Active.Max',
#  'Subflow.Fwd.Bytes',
#  'Bwd.IAT.Min',
#  'Init_Win_bytes_backward',
#  'CWE.Flag.Count',
#  'Bwd.Header.Length',
#  'ECE.Flag.Count',
#  'SYN.Flag.Count',
#  'Bwd.IAT.Total',
#  'Fwd.URG.Flags',
#  'Fwd.Avg.Bulk.Rate',
#  'Max.Packet.Length']

# %%
data[num_cols].describe()
# Out:
#        Fwd.Packet.Length.Min   Flow.IAT.Std  Flow.IAT.Max  Total.Fwd.Packets  \
# count             500.000000     500.000000  5.000000e+02         500.000000
# mean                2.708000   54299.283442  2.400524e+05          17.772000
# std                 7.807474  119352.614671  4.967697e+05          55.177324
# min                 0.000000       0.000000  1.000000e+00           1.000000
# 25%                 0.000000       0.000000  1.340000e+02           2.000000
# 50%                 0.000000   12775.461567  4.500550e+04           5.000000
# 75%                 6.000000   49772.522937  2.033592e+05          11.000000
# max                63.000000  864237.258858  2.939125e+06         588.000000
#
#          Fwd.IAT.Min  Subflow.Bwd.Bytes  Idle.Mean  Idle.Max  \
# count     500.000000       5.000000e+02      500.0     500.0
# mean      860.396000       3.033950e+04        0.0       0.0
# std     12831.757031       1.557811e+05        0.0       0.0
# min         0.000000       0.000000e+00        0.0       0.0
# 25%         0.000000       0.000000e+00        0.0       0.0
# 50%         1.000000       0.000000e+00        0.0       0.0
# 75%       126.500000       1.994250e+03        0.0       0.0
# max    286287.000000       1.354085e+06        0.0       0.0
#
#        Fwd.Packet.Length.Std  Packet.Length.Mean  ...   Bwd.IAT.Min  \
# count             500.000000          500.000000  ...     500.00000
# mean              241.902592          288.304109  ...     845.18600
# std               325.166719          450.205371  ...    9318.26037
# min                 0.000000            0.000000  ...       0.00000
# 25%                 0.000000            6.000000  ...       0.00000
# 50%               111.759877           87.273256  ...       0.00000
# 75%               348.989854          326.913690  ...       0.00000
# max              2257.279410         2497.750000  ...  142405.00000
#
#        Init_Win_bytes_backward  CWE.Flag.Count  Bwd.Header.Length  \
# count               500.000000           500.0         500.000000
# mean               1165.938000             0.0         543.080000
# std                5089.931866             0.0        1850.028405
# min                  -1.000000             0.0           0.000000
# 25%                  -1.000000             0.0           0.000000
# 50%                 137.500000             0.0          62.000000
# 75%                 384.750000             0.0         300.000000
# max               35141.000000             0.0       18784.000000
#
#        ECE.Flag.Count  SYN.Flag.Count  Bwd.IAT.Total  Fwd.URG.Flags  \
# count           500.0      500.000000   5.000000e+02          500.0
# mean              0.0        0.122000   1.599537e+05            0.0
# std               0.0        0.327614   3.031673e+05            0.0
# min               0.0        0.000000   0.000000e+00            0.0
# 25%               0.0        0.000000   0.000000e+00            0.0
# 50%               0.0        0.000000   2.600000e+01            0.0
# 75%               0.0        0.000000   2.188165e+05            0.0
# max               0.0        1.000000   2.870678e+06            0.0
#
#        Fwd.Avg.Bulk.Rate  Max.Packet.Length
# count              500.0         500.000000
# mean                 0.0        1442.114000
# std                  0.0        2081.255361
# min                  0.0           0.000000
# 25%                  0.0           6.000000
# 50%                  0.0         517.000000
# 75%                  0.0        1970.000000
# max                  0.0       11584.000000
#
# [8 rows x 81 columns]

# %%
[col for col in num_cols if data[col].isnull().any()]
# Out:
# []

# %%
cols_for_hist = [col for col in num_cols if data[col].nunique() <= 50]
cols_for_hist, len(cols_for_hist)
# Out:
# (['Fwd.Packet.Length.Min',
#   'Idle.Mean',
#   'Idle.Max',
#   'Bwd.URG.Flags',
#   'Active.Std',
#   'Bwd.Avg.Packets.Bulk',
#   'Active.Mean',
#   'Bwd.Packet.Length.Min',
#   'Bwd.Avg.Bytes.Bulk',
#   'RST.Flag.Count',
#   'Idle.Min',
#   'Fwd.Avg.Packets.Bulk',
#   'L7Protocol',
#   'Protocol',
#   'Bwd.PSH.Flags',
#   'URG.Flag.Count',
#   'FIN.Flag.Count',
#   'Idle.Std',
#   'Fwd.Avg.Bytes.Bulk',
#   'Active.Min',
#   'Min.Packet.Length',
#   'Bwd.Avg.Bulk.Rate',
#   'ACK.Flag.Count',
#   'min_seg_size_forward',
#   'PSH.Flag.Count',
#   'Down.Up.Ratio',
#   'Fwd.PSH.Flags',
#   'Active.Max',
#   'CWE.Flag.Count',
#   'ECE.Flag.Count',
#   'SYN.Flag.Count',
#   'Fwd.URG.Flags',
#   'Fwd.Avg.Bulk.Rate'],
#  33)

# %%
cols_for_desc = [col for col in num_cols if data[col].nunique() > 50]
cols_for_desc
# Out:
# ['Flow.IAT.Std',
#  'Flow.IAT.Max',
#  'Total.Fwd.Packets',
#  'Fwd.IAT.Min',
#  'Subflow.Bwd.Bytes',
#  'Fwd.Packet.Length.Std',
#  'Packet.Length.Mean',
#  'Init_Win_bytes_forward',
#  'Fwd.Header.Length.1',
#  'Fwd.IAT.Max',
#  'Avg.Bwd.Segment.Size',
#  'Source.Port',
#  'Bwd.Packet.Length.Std',
#  'Flow.IAT.Min',
#  'Fwd.IAT.Mean',
#  'Bwd.IAT.Mean',
#  'Bwd.Packet.Length.Max',
#  'Total.Backward.Packets',
#  'Fwd.Packet.Length.Max',
#  'Flow.Duration',
#  'Flow.IAT.Mean',
#  'Fwd.Packets.s',
#  'Packet.Length.Std',
#  'Average.Packet.Size',
#  'Flow.Bytes.s',
#  'Bwd.IAT.Std',
#  'Destination.Port',
#  'Total.Length.of.Fwd.Packets',
#  'Subflow.Fwd.Packets',
#  'Bwd.IAT.Max',
#  'Fwd.Header.Length',
#  'act_data_pkt_fwd',
#  'Bwd.Packets.s',
#  'Flow.Packets.s',
#  'Subflow.Bwd.Packets',
#  'Bwd.Packet.Length.Mean',
#  'Fwd.Packet.Length.Mean',
#  'Total.Length.of.Bwd.Packets',
#  'Avg.Fwd.Segment.Size',
#  'Fwd.IAT.Std',
#  'Fwd.IAT.Total',
#  'Packet.Length.Variance',
#  'Subflow.Fwd.Bytes',
#  'Bwd.IAT.Min',
#  'Init_Win_bytes_backward',
#  'Bwd.Header.Length',
#  'Bwd.IAT.Total',
#  'Max.Packet.Length']

# %%
corr = data[num_cols].corr()

# %%
ipdata = data.copy()

# %%
print("No. of unique values in Timestamp column :",ipdata['Timestamp'].nunique())
print("No. of unique values in FlowID column :",ipdata['Flow.ID'].nunique())
# Out:
# No. of unique values in Timestamp column : 5
# No. of unique values in FlowID column : 308

# %%
ipdata.drop(['Timestamp', 'Flow.ID'], axis = 1, inplace = True)

# %%
single_unique_cols = [col for col in ipdata.columns if ipdata[col].nunique() == 1]
single_unique_cols
# Out:
# ['Protocol',
#  'Bwd.PSH.Flags',
#  'Fwd.URG.Flags',
#  'Bwd.URG.Flags',
#  'RST.Flag.Count',
#  'CWE.Flag.Count',
#  'ECE.Flag.Count',
#  'Fwd.Avg.Bytes.Bulk',
#  'Fwd.Avg.Packets.Bulk',
#  'Fwd.Avg.Bulk.Rate',
#  'Bwd.Avg.Bytes.Bulk',
#  'Bwd.Avg.Packets.Bulk',
#  'Bwd.Avg.Bulk.Rate',
#  'Active.Mean',
#  'Active.Std',
#  'Active.Max',
#  'Active.Min',
#  'Idle.Mean',
#  'Idle.Std',
#  'Idle.Max',
#  'Idle.Min',
#  'Label']

# %%
ipdata.drop(single_unique_cols, axis = 1, inplace = True)

# %%
ip_add_cols = ['Source.IP', 'Source.Port', 'Destination.IP', 'Destination.Port']
ipdata[ip_add_cols]
# Out:
#          Source.IP  Source.Port  Destination.IP  Destination.Port
# 0      172.19.1.46        52422      10.200.7.7              3128
# 1       10.200.7.7         3128     172.19.1.46             52422
# 2     50.31.185.39           80    10.200.7.217             38848
# 3     50.31.185.39           80    10.200.7.217             38848
# 4    192.168.72.43        55961      10.200.7.7              3128
# ..             ...          ...             ...               ...
# 495   10.200.7.195        41578     179.1.4.238               443
# 496   10.200.7.195        44860  216.58.202.225               443
# 497  192.168.42.31        52688      10.200.7.5              3128
# 498  192.168.42.31        52689      10.200.7.5              3128
# 499     10.200.7.5         3128   192.168.42.31             52688
#
# [500 rows x 4 columns]

# %%
ipdata.drop(ip_add_cols, axis = 1, inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder().fit(ipdata['ProtocolName'])
ipdata['ProtocolName'] = encoder.fit_transform(ipdata['ProtocolName'])
ipdata['ProtocolName']
# Out:
# 0       7
# 1       7
# 2       5
# 3       5
# 4       7
#        ..
# 495    11
# 496    11
# 497     4
# 498     4
# 499     5
# Name: ProtocolName, Length: 500, dtype: int32

# %%
ipdata.head(10)
# Out:
#    Flow.Duration  Total.Fwd.Packets  Total.Backward.Packets  \
# 0          45523                 22                      55
# 1              1                  2                       0
# 2              1                  3                       0
# 3            217                  1                       3
# 4          78068                  5                       0
# 5         105069                136                       0
# 6         104443                  5                       0
# 7          11002                  3                      12
# 8         108503                 10                       6
# 9         118415                  7                       0
#
#    Total.Length.of.Fwd.Packets  Total.Length.of.Bwd.Packets  \
# 0                          132                       110414
# 1                           12                            0
# 2                          674                            0
# 3                            0                            0
# 4                         1076                            0
# 5                       313554                            0
# 6                         1076                            0
# 7                          232                         3664
# 8                         6904                         1302
# 9                         2210                            0
#
#    Fwd.Packet.Length.Max  Fwd.Packet.Length.Min  Fwd.Packet.Length.Mean  \
# 0                      6                      6                6.000000
# 1                      6                      6                6.000000
# 2                    337                      0              224.666667
# 3                      0                      0                0.000000
# 4                    529                      6              215.200000
# 5                   5840                      6             2305.544118
# 6                    529                      6              215.200000
# 7                    226                      0               77.333333
# 8                   1448                      0              690.400000
# 9                   1096                      0              315.714286
#
#    Fwd.Packet.Length.Std  Bwd.Packet.Length.Max  ...  Subflow.Fwd.Packets  \
# 0               0.000000                   4380  ...                   22
# 1               0.000000                      0  ...                    2
# 2             194.567041                      0  ...                    3
# 3               0.000000                      0  ...                    1
# 4             286.458898                      0  ...                    5
# 5            1220.822406                      0  ...                  136
# 6             286.458898                      0  ...                    5
# 7             128.784057                   3628  ...                    3
# 8             660.894209                   1302  ...                   10
# 9             533.043374                      0  ...                    7
#
#    Subflow.Fwd.Bytes  Subflow.Bwd.Packets  Subflow.Bwd.Bytes  \
# 0                132                   55             110414
# 1                 12                    0                  0
# 2                674                    0                  0
# 3                  0                    3                  0
# 4               1076                    0                  0
# 5             313554                    0                  0
# 6               1076                    0                  0
# 7                232                   12               3664
# 8               6904                    6               1302
# 9               2210                    0                  0
#
#    Init_Win_bytes_forward  Init_Win_bytes_backward  act_data_pkt_fwd  \
# 0                     256                      490                21
# 1                     490                       -1                 1
# 2                     888                       -1                 1
# 3                     888                      490                 0
# 4                     253                       -1                 4
# 5                     254                       -1               135
# 6                     253                       -1                 4
# 7                    8192                      245                 2
# 8                      60                     1000                 7
# 9                    8192                       -1                 5
#
#    min_seg_size_forward  L7Protocol  ProtocolName
# 0                    20         131             7
# 1                    20         131             7
# 2                    32           7             5
# 3                    32           7             5
# 4                    20         131             7
# 5                    20         131             7
# 6                    20         131             7
# 7                    20         130             6
# 8                    32          91             9
# 9                    20         126             4
#
# [10 rows x 59 columns]

# %%
ipdata.shape
# Out:
# (500, 59)

# %%
data.dropna(inplace = True)

# %%
def ipInfo(addr=''):
    from urllib.request import urlopen
    from json import load
    if addr == '':
        url = 'https://ipinfo.io/json'
    else:
        url = 'https://ipinfo.io/' + addr + '/json'
    res = urlopen(url)
    
    data = load(res)
    
    for attr in data.keys():
        
        print(attr,' '*13+'\t->\t',data[attr])
data.drop(columns =["Timestamp"], inplace = True)

# %%
data.drop(columns =["Label"], inplace = True)
df2 = data

# %%
df2.drop(columns =["Source.IP", "Source.Port", "Destination.IP", "Destination.Port"], inplace = True) #better way is to replace it with country using some lib like geo2ip but I am lazy
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
df2["labels"] = lb_make.fit_transform(df2["ProtocolName"])
df2[["ProtocolName", "labels"]].head(11)
# Out:
#     ProtocolName  labels
# 0     HTTP_PROXY       7
# 1     HTTP_PROXY       7
# 2           HTTP       5
# 3           HTTP       5
# 4     HTTP_PROXY       7
# 5     HTTP_PROXY       7
# 6     HTTP_PROXY       7
# 7   HTTP_CONNECT       6
# 8            SSL       9
# 9         GOOGLE       4
# 10    HTTP_PROXY       7

# %%
from sklearn.model_selection import train_test_split
# !pip install '/content/drive/My Drive/lib-0.1.0-py3-none-any.whl'
y = df2.iloc[:,-1]
from lib.utils import *
X,y=scaler_transform(df2)
ac=[]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)
X_train.shape, y_train.shape
ac=[]
# Out:
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\vc\appdata\roaming\python\python36\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\vc\appdata\local\programs\python\python36\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\vc\appdata\local\programs\python\python36\lib\site-packages)
# ERROR: Invalid requirement: "'/content/drive/My"
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\vc\appdata\roaming\python\python36\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\vc\appdata\local\programs\python\python36\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\vc\appdata\local\programs\python\python36\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\vc\appdata\roaming\python\python36\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\vc\appdata\local\programs\python\python36\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\vc\appdata\local\programs\python\python36\lib\site-packages)

# %%
ac=[]

import random
from sklearn.linear_model import Ridge
model = Ridge(alpha=1.0)

def objective_function(x):
    return x**2  


class Particle:
    def __init__(self):
        self.position = random.uniform(-5, 5)  
        self.velocity = random.uniform(-1, 1)  
        self.best_position = self.position  
        self.best_score = float('inf')  #

    def particle_swarm_optimization(self,num_particles, num_iterations):
        particles = [Particle() for _ in range(num_particles)]  
        global_best_position = None  
        global_best_score = float('inf')  

        for _ in range(num_iterations):
            for particle in particles:
                score = objective_function(particle.position)  
                if score < particle.best_score:
                    particle.best_score = score
                    particle.best_position = particle.position

                if score < global_best_score:
                    global_best_score = score
                    global_best_position = particle.position


                inertia_weight = 0.5
                cognitive_weight = 0.5
                social_weight = 0.5
                particle.velocity = (inertia_weight * particle.velocity +
                                     cognitive_weight * random.random() * (particle.best_position - particle.position) +
                                     social_weight * random.random() * (global_best_position - particle.position))
                particle.position += particle.velocity

        return global_best_position, global_best_score

    def train(self,X_train,y_train,X_test):
        model.fit(X_train,y_train)
        y_pred=model.predict(X_test)
        return y_pred

num_particles = 30  
num_iterations = 100 
p=Particle()
best_position, best_score =p.particle_swarm_optimization(num_particles, num_iterations)

y_pred=p.train(X_train,y_train,X_test)
print("Best Position:", best_position)
print("Best Score:", best_score)
ac.append(accuracy_score(y_pred,y_train,sample_weight=0.2)*100)
# Out:
# Best Position: -9.503128952590806e-18
# Best Score: 9.030945988956963e-35

# %%
import random
import math

class ButterflyOptimizationAlgorithm:
    def __init__(self, num_butterflies=20, num_iterations=100, search_space_lower_bound=-10, search_space_upper_bound=10):
        self.num_butterflies = num_butterflies
        self.num_iterations = num_iterations
        self.search_space_lower_bound = search_space_lower_bound
        self.search_space_upper_bound = search_space_upper_bound

    def _initialize_butterflies(self):
        return [random.uniform(self.search_space_lower_bound, self.search_space_upper_bound) for _ in range(self.num_butterflies)]

    def _fitness_function(self, solution):
        
        return sum(x ** 2 for x in solution)

    def optimize(self):
        butterflies = self._initialize_butterflies()
        best_solution = None
        best_fitness = float('inf')

        for iteration in range(self.num_iterations):
            a = random.random()  
            b = 1 - (iteration / self.num_iterations) ** a  
            
            for i in range(self.num_butterflies):
                r1, r2 = random.random(), random.random()  
                A = r1 * butterflies[i]  
                B = r2 * best_solution if r2 < 0.5 else r2 * random.choice(butterflies)  

                
                new_solution = (b * A) + ((1 - b) * B)
                
                
                new_solution = max(min(new_solution, self.search_space_upper_bound), self.search_space_lower_bound)
                
                
                fitness_new = self._fitness_function(new_solution)
                fitness_butterfly = self._fitness_function(butterflies[i])

                
                if fitness_new < fitness_butterfly:
                    butterflies[i] = new_solution

                    
                    if fitness_new < best_fitness:
                        best_solution = new_solution
                        best_fitness = fitness_new

        return best_solution, best_fitness
    def train(self,X_train,y_train,X_test):
        model.fit(X_train,y_train)
        y_pred=model.predict(X_test)
        return y_pred



num_butterflies = 20
num_iterations = 100
search_space_lower_bound = -10
search_space_upper_bound = 10

boa = ButterflyOptimizationAlgorithm(num_butterflies=num_butterflies, num_iterations=num_iterations, search_space_lower_bound=search_space_lower_bound, search_space_upper_bound=search_space_upper_bound)
y_pred=boa.train(X_train,y_train,X_test)

ac.append(accuracy_score(y_pred,y_train,sample_weight=1)*100)

# %%
from scipy import signal
import numpy as np
sig = np.repeat([0., 1., 1., 0., 1., 0., 0., 1.], 128)
sig_noise = sig + np.random.randn(len(sig))
corr = signal.correlate(sig_noise, np.ones(128), mode='same') / 128
import matplotlib.pyplot as plt
clock = np.arange(64, len(sig), 128)
fig, (ax_orig, ax_noise, ax_corr) = plt.subplots(3, 1, sharex=True)
ax_orig.plot(sig)
ax_orig.plot(clock, sig[clock], 'ro')
ax_orig.set_title('Original signal')
ax_noise.plot(sig_noise)
ax_noise.set_title('Signal with noise')
ax_corr.plot(corr)
ax_corr.plot(clock, corr[clock], 'ro')
ax_corr.axhline(0.5, ls=':')
ax_corr.set_title('Cross-correlated with rectangular pulse')
ax_orig.margins(0, 0.1)
fig.tight_layout()
fig.show()
# Out:
# C:\Users\VC\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
import numpy as np
import seaborn as sns
import matplotlib as plt

plt.style.use('dark_background')
x=['PSO','Butterfly Optimization']
 
ax=sns.barplot(x,ac[:2])
ax.set_title('Accuracy comparison')
ax.set_ylabel('Accuracy')
#ax.yaxis.set_major_locator(ticker.LinearLocator())
print("the accuracy of {} is {} and {} is {}".format(x[0],ac[0],x[1],ac[1]))
ax.set_ylim(50,100)
import pandas as pd
data={'Agorithms':x,
     "accuracy":ac[:2]}
df=pd.DataFrame(data)
df.head()
# Out:
# the accuracy of PSO is 97.27 and GHO is 88.2
# C:\Users\VC\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   Agorithms  accuracy
# 0       PSO     97.27
# 1       GHO     88.20

# %%
ac
# Out:
# [97.27, 88.2, 92.12, 93.89, 95.71]
